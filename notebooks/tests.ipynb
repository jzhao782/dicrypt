# %%
import pandas as pd

# %%
X = pd.read_csv('../data/X.csv', index_col='Unnamed: 0')
y = pd.read_csv('../data/y.csv', index_col='Unnamed: 0')

# %%
full = pd.read_csv('../archived/parsed_data_truncated_v1.csv')

# %%
full.is_mp.value_counts()
# Out:
# True     31939
# False      228
# Name: is_mp, dtype: int64

# %%
full[full.id == 3524]
# Out:
#        Unnamed: 0    id  is_mp   density  H  He  Li  Be  B  C  ...  W  Re  Os  \
# 23039       23039  3524   True  2.874445  0   0   1   0  0  0  ...  0   0   0
# 32118       32118  3524  False  3.162682  0   0   0   0  0  0  ...  0   0   0
#
#        Ir  Pt  Au  Hg  Tl  Pb  Bi
# 23039   0   0   0   0   0   0   0
# 32118   0   0   0   0   0   0   0
#
# [2 rows x 87 columns]

# %%
y['is_mp'] = full.is_mp

# %%
y = y[y.is_mp]

# %%
y
# Out:
#          Density  is_mp
# 0       1.935039   True
# 1       6.064410   True
# 2      13.343942   True
# 3       4.937886   True
# 4      11.035294   True
# ...          ...    ...
# 31934   7.196625   True
# 31935   8.117297   True
# 31936   8.157901   True
# 31937   8.593083   True
# 31938   8.688206   True
#
# [31939 rows x 2 columns]

# %%
X['is_mp'] = full.is_mp
X = X[X.is_mp]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X
# Out:
#        MagpieData minimum Number  MagpieData maximum Number  \
# 0                           55.0                       55.0
# 1                           33.0                       33.0
# 2                           72.0                       72.0
# 3                           52.0                       56.0
# 4                           16.0                       72.0
# ...                          ...                        ...
# 31934                       14.0                       28.0
# 31935                       25.0                       51.0
# 31936                       14.0                       44.0
# 31937                       33.0                       42.0
# 31938                        5.0                       42.0
#
#        MagpieData range Number  MagpieData mean Number  \
# 0                          0.0               55.000000
# 1                          0.0               33.000000
# 2                          0.0               72.000000
# ...

# %%
def rename_ids(row):
    row.id = 'mp-' + str(row.id) if row.is_mp else 'mvc-' + str(row.id)
    return row

full = full.apply(rename_ids, axis=1)

# %%
pd.Series(full.id).to_csv('../data/ids.csv')
